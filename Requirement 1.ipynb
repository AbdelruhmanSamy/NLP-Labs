# %%
# Type your full name
student1_full_name = "Abdelruhman Sami Mohamad"

# Type your section 1 or 2
student1_section = "1"

# Type your BN
student1_BN = "29"

###########################################
# Type your full name
student2_full_name = "Abdullah Salah Salem"

# Type your section 1 or 2
student2_section = "1"

# Type your BN
student2_BN = "32"

# %%
import re
# if you don't have pandas, uncomment the next line
# !pip install pandas
import pandas as pd

# %% [markdown]
# # Task Description
#
# In this task, you will work with text file containing several emails with their body and other information like sender email, date, subject etc...
#
# Dataset Link: https://www.kaggle.com/datasets/rtatman/fraudulent-email-corpus
#
# Download the dataset then rename the text file to: emails_dataset.txt
#
# The goal of this requirement is to process this text file to convert it to a pandas dataframe to be used easily later. First of all, you need open the text file and try to familiarize yourself with it.
#
# Your task will be implementing the TODOs only. Don't write any code out side the TODOs or change other code of this notebook. You will also need to run all the cells in sequence to produce the final output file to be submitted.

# %%
# Let's read the emails text file
f = open(r"emails_dataset.txt", "r").read()
print(type(f))
# Out:
# <class 'str'>

# %% [markdown]
# Now, we have the whole emails in one string. The first thing we need to do is to split this string to a list containing separate emails. To do this you need to discover the text file. You will notice that every email always starts by a fixed pattern. Your task is to discover what this pattern is to split the string on.

# %%
######################### TODO: write the pattern to split the emails on in the raw string below ######################
start_email_pattern = r"From r\s"
#######################################################################################################################

contents = re.split(start_email_pattern, f)
contents.pop(0)
print(len(contents))
assert len(contents) == 3976, "Your pattern is wrong"
# Out:
# 3976

# %% [markdown]
# # Information to be collected
#
# Since we now have a list with all emails, we can iterate over them to collect the information we need. Your task will be to implement some functions using Regular Expressions to collect the following information:
# 1. Sender Email
# 2. Sender Name
# 3. Recipient Email
# 4. Recipient Name
# 5. Date
# 6. Subject

# %%
# This function takes a full email (from the contents list)
# and returns both the sender email and name as strings
# To deremine this, look at the original text file and answer the following questions
# what is the pattern that start the line containing both sender name and email?
# If you get this whole line, how to capture the email?
# If you get this whole line, how to capture the name?

def senderEmailAndName(email_item):
    ###################### TODO: write regex that can match the whole line containing the sender name and email #########
    sender_name_email_line_regex = r'From:\s"{0,1}.*"{0,1}\s<.*>'
    #####################################################################################################################
    sender = re.search(sender_name_email_line_regex, email_item)
    # This check is in case there is no sender found (We don't know if all emails contain this info)
    if sender is not None:
        # Since we have the line You need to do the following
        # You can capture the email by using only one regex (only one re.search())
        # To capture the name safely you can write regex that captures all characters from the end of the start line pattern
        # to the pattern the starts the email
        
        ######################### TODO: write regex that captures the email, and the name #############################
        # email regex: this will capture the email exactly
        email_regex = r"(?<=<).*(?=>)"
        # name regex: this will capture the name besides some characters before and after it that will be removed later
        name_regex = r'(?<=From:\s).*(?=\s*<.*>)'
        ##############################################################################################################
        s_email = re.search(email_regex, sender.group())
        s_name = re.search(name_regex, sender.group())
    else:
        s_email = None
        s_name = None

    # We need to check as re.search() may return None
    if s_email is not None:
        sender_email = s_email.group()
    else:
        sender_email = None

    # We need to check as re.search() may return None
    if s_name is not None:
        # Since the name is not captured exactly, we need to substitute all unneeded characters
        
        ############################# TODO: write regex to capture characters to be removed #####################
        characters_remove_from_beginning = '^\s*"|"\s*|^[\s\']+'
        characters_remove_from_end = '[\s"\']+$'
        #########################################################################################################
        sender_name = re.sub(characters_remove_from_end, "", re.sub(characters_remove_from_beginning, "", s_name.group()))
    else:
        sender_name = None

    return sender_email, sender_name
# Out:
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:44: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_10659/50692424.py:43: SyntaxWarning: invalid escape sequence '\s'
#   characters_remove_from_beginning = '^\s*"|"\s*|^[\s\']+'
# /tmp/ipykernel_10659/50692424.py:44: SyntaxWarning: invalid escape sequence '\s'
#   characters_remove_from_end = '[\s"\']+$'

# %%
# This function takes a full email (from the contents list)
# and returns both the recipient email and name as strings
# You will do exactly the same thing you did for sender email except for the pattern used to capture the line
# containing the recipient

def recipientEmailAndName(email_item):
    ###################### TODO: write regex that can match the whole line containing the recipient name and email #########
    recipient_name_email_line_regex = r"To:\s.*<.*>"
    #####################################################################################################################
    recipient = re.search(recipient_name_email_line_regex, email_item)
    print(recipient)
    # This check is in case there is no sender found (We don't know if all emails contain this info)
    if recipient is not None:
        # Since we have the line You need to do the following
        # You can capture the email by using only one regex (only one re.search())
        # To capture the name safely you can write regex that captures all characters from the end of the start line pattern
        # to the pattern the starts the email
        
        ######################### TODO: write regex that captures the email, and the name #############################
        # email regex: this will capture the email exactly
        email_regex = r"(?<=<).*@.*(?=>) | \b.*@.*\b"
        # name regex: this will capture the name besides some characters before and after it that will be removed later
        name_regex = r"(?<=To:\s).*(?=\s*<)"
        ##############################################################################################################
        r_email = re.search(email_regex, recipient.group())
        r_name = re.search(name_regex, recipient.group())
    else:
        r_email = None
        r_name = None

    # We need to check as re.search() may return None
    if r_email is not None:
        recipient_email = r_email.group()
    else:
        recipient_email = None

    # We need to check as re.search() may return None
    if r_name is not None:
        # Since the name is not captured exactly, we need to substitute all unneeded characters
        
        ############################# TODO: write regex to capture characters to be removed #####################
        characters_remove_from_beginning = '^\s*"|"\s*|^[\s\']+'
        characters_remove_from_end = '[\s"\']+$'
        #########################################################################################################
        recipient_name = re.sub(characters_remove_from_end, "", re.sub(characters_remove_from_beginning, "", r_name.group()))
    else:
        recipient_name = None

    return recipient_email, recipient_name
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:43: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_10659/1438498480.py:42: SyntaxWarning: invalid escape sequence '\s'
#   characters_remove_from_beginning = '^\s*"|"\s*|^[\s\']+'
# /tmp/ipykernel_10659/1438498480.py:43: SyntaxWarning: invalid escape sequence '\s'
#   characters_remove_from_end = '[\s"\']+$'

# %%
# This function takes a full email and returns a string with the date

def getDate(email_item):
    ########################### TODO: write regex to match the whole line containing the date ########################
    line_date_regex = r"Date:\s+.{3},\s+\d{1,2}\s+.{3}\s+\d{4}\s+\d{2}:\d{2}:\d{2}"
    ##################################################################################################################
    date_field = re.search(line_date_regex, email_item)

    if date_field is not None:
        #################################### TODO: write regex to match only the date ###############################
        # e.g. If the date is: Thu, 31 Oct 2002 22:17:55 +0100
        # you need to match only 31 Oct 2002
        date_only_regex = r"\d{1,2} [a-zA-Z]{3} \d{4}"
        #############################################################################################################
        date = re.search(date_only_regex, date_field.group())
    else:
        date = None

    if date is not None:
        date_sent = date.group()
    else:
        date_sent = None

    return date_sent

# %%
# This function takes a full email item and returns a string with the email subject
def getSubject(email_item):
    ########################## TODO: write regex to match the whole line containing the subject #################
    line_subject_regex = r"Subject:.*"
    #############################################################################################################
    subject_field = re.search(line_subject_regex, email_item)

    if subject_field is not None:
        #################### TODO: write regex with the pattern to be removed to capture the subject only ##########
        remove_pattern = r"Subject:\s*"
        ############################################################################################################
        subject = re.sub(remove_pattern, "", subject_field.group())
    else:
        subject = None

    return subject

# %%
# Let's construct our emails
emails = []
for email_item in contents:
    emails_dict = {}
    emails_dict["sender_email"], emails_dict["sender_name"] = senderEmailAndName(email_item)
    emails_dict["recipient_email"], emails_dict["recipient_name"] = recipientEmailAndName(email_item)
    emails_dict["date_sent"] = getDate(email_item)
    emails_dict["subject"] = getSubject(email_item)
    
    emails.append(emails_dict)
    
assert len(emails) == 3976, "You have something wrong"
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(257, 266), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(235, 283), match='To: " resbob@al-islam.com" <resbob@al-islam.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(355, 381), match='To: <savimbidenis@www.com>'>
# None
# None
# None
# None
# <re.Match object; span=(418, 481), match='To: "=?iso-8859-1?Q?lawrence.smith?=" <lawrence.s>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(141, 187), match='To: "chukwu mike" <mikechukwu32@primposta.com>'>
# <re.Match object; span=(141, 187), match='To: "chukwu mike" <mikechukwu32@primposta.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(183, 239), match='To: <20030206175043.73568.qmail@web13206.mail.yah>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(261, 270), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(74, 125), match='To: "elisabth  lamine" <leezbt_qeen@rediffmail.co>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(219, 268), match='To: "webmaster@aclweb.org" <webmaster@aclweb.org>>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(100, 109), match='To: <R@S>'>
# None
# <re.Match object; span=(153, 168), match='To: "R@M" <R@M>'>
# None
# <re.Match object; span=(176, 222), match='To: "grace abba-gana" <gabbagana@albawaba.com>'>
# <re.Match object; span=(316, 351), match='To: <salatu_ibru100@indiatimes.com>'>
# None
# <re.Match object; span=(164, 213), match='To: "astrada@kukamail.com" <astrada@kukamail.com>>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(178, 187), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(180, 227), match='To: "godfrey eche3" <godfreyeche3@albawaba.com>'>
# <re.Match object; span=(180, 227), match='To: "godfrey eche3" <godfreyeche3@albawaba.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(60, 105), match='To: "s.kaa@katamail.com" <s.kaa@katamail.com>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(364, 412), match='To: =?iso-8859-1?Q?makathy?= <makathy@libero.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(226, 241), match='To: Rrrrr <R@S>'>
# <re.Match object; span=(270, 285), match='To: Rrrrr <R@E>'>
# <re.Match object; span=(226, 241), match='To: Rrrrr <R@M>'>
# None
# <re.Match object; span=(191, 200), match='To: <R@M>'>
# <re.Match object; span=(246, 261), match='To: Rrrrr <R@S>'>
# <re.Match object; span=(246, 261), match='To: Rrrrr <R@E>'>
# <re.Match object; span=(246, 261), match='To: Rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(372, 416), match='To: <savimbicar1dogmail.co.uk@dogmail.co.uk>'>
# None
# None
# None
# None
# <re.Match object; span=(163, 210), match='To: "SI2003@kukamail.com" <SI2003@kukamail.com>'>
# None
# None
# <re.Match object; span=(166, 208), match='To: <llavanwa@UM>, <rossah@UM>, <jfine@UM>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(373, 399), match='To: <mcabacha@freesurf.fr>'>
# None
# None
# None
# <re.Match object; span=(301, 328), match='To: <ifeanyi_uzo@yahoo.com>'>
# None
# None
# None
# <re.Match object; span=(320, 349), match='To: <2003vincent@freesurf.fr>'>
# None
# <re.Match object; span=(286, 315), match='To: <jerrypeter2@freesurf.fr>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(160, 189), match='To: <info-www-search@ISI.EDU>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(223, 251), match='To: <yetunde@mail2world.com>'>
# <re.Match object; span=(223, 251), match='To: <yetunde@mail2world.com>'>
# None
# None
# <re.Match object; span=(382, 408), match='To: <fredkuma@freesurf.fr>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(477, 537), match='To: =?us-ascii?Q?jide=20williams?= <jide.williams>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(64, 117), match='To: "zainabuba@katamail.com" <zainabuba@katamail.>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(320, 366), match='To: "patelnikes4you" <patelnikes4you@yahoo.ca>'>
# <re.Match object; span=(322, 368), match='To: "patelnikes4you" <patelnikes4you@yahoo.ca>'>
# <re.Match object; span=(322, 368), match='To: "patelnikes4you" <patelnikes4you@yahoo.ca>'>
# None
# <re.Match object; span=(421, 473), match='To: =?us-ascii?Q?mogua=20mogogo?= <moguam@seznam.>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(157, 166), match='To: <R@M>'>
# <re.Match object; span=(94, 103), match='To: <R@S>'>
# <re.Match object; span=(157, 166), match='To: <R@M>'>
# <re.Match object; span=(152, 161), match='To: <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(165, 200), match='To: <babatundepedro1@tiscali.co.uk>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(319, 352), match='To: "mjaja02" <mjaja02@libero.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(300, 335), match='To: kufor2000 <kufor100@uymail.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(189, 245), match='To: <20031018004101.97628.qmail@web41002.mail.yah>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(305, 340), match='To: kufor_1000 <kufor40@fsmail.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(89, 98), match='To: <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(327, 370), match='To: "jeffersila04" <jeffersila04@libero.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(326, 365), match='To: "dr_frances" <dr_frances@libero.it>'>
# <re.Match object; span=(326, 365), match='To: "dr_frances" <dr_frances@libero.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(656, 728), match='To: President/Ceo<BR>From:Daniel Kabila<BR>Johann>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(313, 356), match='To: "markduke2004" <markduke2004@libero.it>'>
# None
# <re.Match object; span=(264, 295), match='To: <barristerpeter2@emaila.nu>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(246, 294), match='To: "williams\\.onwa" <williams.onwa@laposte.net>>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(111, 140), match='To: <steinjammy@netscape.net>'>
# None
# None
# None
# <re.Match object; span=(237, 274), match='To: "larry_ed1" <larry_ed1@libero.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(35, 77), match='To:  <40C3E3930000059F@mail04.jumpyint.it>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(499, 508), match='To: <R@E>'>
# <re.Match object; span=(455, 464), match='To: <R@E>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(280, 315), match='To: <charityattention@netscape.net>'>
# <re.Match object; span=(242, 277), match='To: <charityattention@netscape.net>'>
# <re.Match object; span=(282, 317), match='To: <charityattention@netscape.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(288, 335), match='To: "Shadak Shari" <shadak_shari5@albawaba.com>'>
# <re.Match object; span=(288, 335), match='To: "Shadak Shari" <shadak_shari6@albawaba.com>'>
# <re.Match object; span=(285, 331), match='To: "Shadak Shari" <shadak_shari@albawaba.com>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(218, 233), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(209, 252), match='To: "info@crack-ag.com" <info@crack-ag.com>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(248, 264), match='To: "Joey" <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(510, 519), match='To: <R@E>'>
# <re.Match object; span=(467, 476), match='To: <R@E>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(263, 289), match='To: <dasuki3@netscape.net>'>
# <re.Match object; span=(266, 292), match='To: <dasuki3@netscape.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(1669, 1707), match='To: Mrs Jane Mupesa <mrssjane@mail.ru>'>
# None
# None
# <re.Match object; span=(190, 207), match='To: "rrrrr" <R@S>'>
# None
# None
# <re.Match object; span=(299, 331), match='To: <taofeekmarvin@netscape.net>'>
# <re.Match object; span=(300, 332), match='To: <taofeekmarvin@netscape.net>'>
# None
# <re.Match object; span=(293, 325), match='To: <taofeekmarvin@netscape.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(184, 193), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(309, 334), match='To: <web-11383337@ozu.es>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(193, 202), match='To: <R@M>'>
# <re.Match object; span=(346, 355), match='To: <R@E>'>
# <re.Match object; span=(302, 311), match='To: <R@E>'>
# None
# None
# <re.Match object; span=(288, 320), match='To: <mrskatekoroma@netscape.net>'>
# <re.Match object; span=(332, 364), match='To: <mrskatekoroma@netscape.net>'>
# <re.Match object; span=(240, 279), match='To: Masesela Dikgale <lokomboh@msn.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(292, 320), match='To: <mrswuyung@netscape.net>'>
# <re.Match object; span=(282, 310), match='To: <mrswuyung@netscape.net>'>
# <re.Match object; span=(326, 354), match='To: <mrswuyung@netscape.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(249, 258), match='To: <R@E>'>
# <re.Match object; span=(293, 302), match='To: <R@E>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(218, 235), match='To: "rrrrr" <R@E>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(233, 248), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# <re.Match object; span=(338, 347), match='To: <R@E>'>
# <re.Match object; span=(294, 303), match='To: <R@E>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(193, 210), match='To: "rrrrr" <R@M>'>
# None
# None
# <re.Match object; span=(188, 205), match='To: "rrrrr" <R@S>'>
# <re.Match object; span=(238, 253), match='To: rrrrr <R@M>'>
# None
# None
# None
# <re.Match object; span=(477, 497), match='To: <kalexa@eecs.UM>'>
# <re.Match object; span=(520, 540), match='To: <kalexa@eecs.UM>'>
# <re.Match object; span=(535, 554), match='To: <laird@eecs.UM>'>
# None
# <re.Match object; span=(149, 202), match='To: "kenneth masuku." <kmasukusituation@netscape.>
# None
# None
# None
# None
# <re.Match object; span=(210, 238), match='To: "danbrown" <danbrown@UM>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(303, 312), match='To: <R@E>'>
# <re.Match object; span=(347, 356), match='To: <R@E>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(1494, 1540), match='To: "SESAY MASSAQUOE." <semassaq@netscape.net>'>
# <re.Match object; span=(98, 138), match='To: "SESAY MASSAQUOE." <semassaq1@o2.pl>'>
# <re.Match object; span=(55, 107), match='To: "SESAY MASSAQUOE." <sesaymassaquoe@netscape.n>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(136, 156), match='To: <alfre1@ixp.net>'>
# <re.Match object; span=(136, 156), match='To: <alfre1@ixp.net>'>
# None
# None
# None
# None
# <re.Match object; span=(298, 329), match='To: <frankmap333@solidmail.com>'>
# None
# None
# None
# None
# <re.Match object; span=(439, 448), match='To: <R@E>'>
# <re.Match object; span=(483, 492), match='To: <R@E>'>
# <re.Match object; span=(182, 191), match='To: <R@S>'>
# <re.Match object; span=(182, 191), match='To: <R@S>'>
# <re.Match object; span=(181, 190), match='To: <R@M>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(474, 483), match='To: <R@E>'>
# <re.Match object; span=(430, 439), match='To: <R@E>'>
# None
# <re.Match object; span=(430, 439), match='To: <R@E>'>
# <re.Match object; span=(474, 483), match='To: <R@E>'>
# None
# <re.Match object; span=(474, 483), match='To: <R@E>'>
# <re.Match object; span=(430, 439), match='To: <R@E>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(214, 229), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(182, 191), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(902, 957), match='To: <20041207204453.3631.qmail@web53005.mail.yaho>
# None
# <re.Match object; span=(185, 194), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(95, 137), match='To:  <40FF87BB000DB773@mail15.jumpyint.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(321, 352), match='To: <wiliamsjohn2008@yahoo.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(229, 244), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(98, 139), match='To: "lucas" <olajidelucas@boa-online.net>'>
# None
# None
# <re.Match object; span=(229, 244), match='To: rrrrr <R@M>'>
# <re.Match object; span=(227, 242), match='To: rrrrr <R@M>'>
# <re.Match object; span=(226, 241), match='To: rrrrr <R@M>'>
# <re.Match object; span=(228, 243), match='To: rrrrr <R@M>'>
# <re.Match object; span=(226, 241), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(1552, 1587), match='To: <a_vlachko03@pro-alliance.info>'>
# <re.Match object; span=(258, 307), match='To: "mohammad urban" <devamatar@members.vrna.org>>
# <re.Match object; span=(215, 264), match='To: "mohammad urban" <devamatar@members.vrna.org>>
# None
# None
# None
# None
# <re.Match object; span=(235, 250), match='To: rrrrr <R@M>'>
# <re.Match object; span=(1678, 1708), match='To: <abacha_abj@mycommail.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(222, 262), match='To: Jerry <JerryPinson@Zoominternet.Net>'>
# None
# None
# <re.Match object; span=(253, 279), match='To: <aduakenzua@pochta.ru>'>
# None
# None
# <re.Match object; span=(138, 164), match='To: <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(149, 208), match='To: "benard_mcarthy@wanadoo.es" <benard_mcarthy@w>
# <re.Match object; span=(149, 208), match='To: "benard_mcarthy@wanadoo.es" <benard_mcarthy@w>
# None
# None
# <re.Match object; span=(240, 255), match='To: rrrrr <R@M>'>
# None
# None
# None
# <re.Match object; span=(262, 271), match='To: <R@E>'>
# <re.Match object; span=(350, 359), match='To: <R@E>'>
# None
# None
# None
# <re.Match object; span=(138, 179), match='To: "KOJO WILLIAM" <kojow_2005@yahoo.com>'>
# None
# None
# <re.Match object; span=(464, 473), match='To: <R@E>'>
# None
# <re.Match object; span=(552, 561), match='To: <R@E>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(228, 243), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(129, 155), match='To: <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(133, 188), match='To: "peterkhan@latinmail.com" <peterkhan@latinmai>
# None
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# <re.Match object; span=(141, 179), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# <re.Match object; span=(145, 183), match='To: "webmaster" <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(198, 219), match='To: <fccinfo@fcc.gov>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(269, 290), match='To: <regroff@eecs.UM>'>
# <re.Match object; span=(357, 378), match='To: <regroff@eecs.UM>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(300, 331), match='To: <joseph_m333@micasilla.net>'>
# <re.Match object; span=(429, 460), match='To: <joseph_m333@micasilla.net>'>
# <re.Match object; span=(343, 374), match='To: <joseph_m333@micasilla.net>'>
# <re.Match object; span=(300, 331), match='To: <joseph_m333@micasilla.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(151, 177), match='To: <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(139, 198), match='To: "moh_yaya005@latinmail.com" <moh_yaya005@lati>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(224, 239), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# <re.Match object; span=(205, 214), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(145, 160), match='To: rrrrr <R@S>'>
# <re.Match object; span=(146, 161), match='To: rrrrr <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(132, 168), match='To: webmaster <webmaster@aclweb.org>'>
# <re.Match object; span=(144, 180), match='To: webmaster <webmaster@aclweb.org>'>
# <re.Match object; span=(142, 178), match='To: webmaster <webmaster@aclweb.org>'>
# <re.Match object; span=(141, 177), match='To: webmaster <webmaster@aclweb.org>'>
# None
# None
# <re.Match object; span=(142, 157), match='To: rrrrr <R@S>'>
# <re.Match object; span=(139, 154), match='To: rrrrr <R@S>'>
# <re.Match object; span=(135, 173), match='To: "Mr.Kabir Bello." <bkabir@she.com>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(306, 343), match='To: <edwardtaibu1@bareed.alburaq.net>'>
# None
# None
# None
# None
# <re.Match object; span=(280, 295), match='To: Rrrrr <R@M>'>
# <re.Match object; span=(281, 317), match='To: Webmaster <webmaster@aclweb.org>'>
# None
# None
# None
# None
# <re.Match object; span=(292, 319), match='To: <d_benton@web2mail.com>'>
# <re.Match object; span=(162, 171), match='To: <R@C>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(163, 180), match='To: "R@M\\r" <R@M>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(188, 223), match='To: <drcharakroultwell@virgilio.it>'>
# <re.Match object; span=(188, 223), match='To: <drcharakroultwell@virgilio.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(289, 319), match='To: <kams_chambers@webnow.com>'>
# <re.Match object; span=(161, 191), match='To: <CHARLESATLAW@JUSTICE.COM>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(303, 348), match='To: "Investment" <sigmod-pods06-webmaster@UM>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(521, 564), match='To: "Mr. Ben Otutu." <bentutu_01@yahoo.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(225, 240), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(261, 316), match='To: "will.wilcox1@virgin.net" <will.wilcox1@virgi>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(345, 384), match='To: julian zanna <julian_zanna@mail.ru>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(277, 346), match='To: "charakroultwells@adinet.com.uy" <charakroult>
# <re.Match object; span=(277, 346), match='To: "charakroultwells@adinet.com.uy" <charakroult>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(136, 180), match='To: "FROM DESSU METHAN" <desuu@caramail.com>'>
# None
# None
# None
# <re.Match object; span=(247, 294), match='To: "vski.ziv@virgin.net" <vski.ziv@virgin.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(167, 209), match='To: "ELIZABETH GARANGE" <elig7@tiscali.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(193, 202), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(321, 330), match='To: <R@M>'>
# None
# <re.Match object; span=(172, 210), match='To: "david" <lseku707wxmcybxr@mail.az>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(140, 149), match='To: <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(146, 163), match='To: "Rrrrr" <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(462, 505), match='To: "sem_bouabre" <sem_bouabre@lycos.co.uk>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(249, 290), match='To: Karonga Zungu <karongaz@netscape.net>'>
# <re.Match object; span=(277, 318), match='To: Karonga Zungu <karongaz@netscape.net>'>
# None
# <re.Match object; span=(249, 290), match='To: Karonga Zungu <karongaz@netscape.net>'>
# None
# <re.Match object; span=(248, 289), match='To: Karonga Zungu <karongaz@netscape.net>'>
# None
# None
# None
# <re.Match object; span=(278, 319), match='To: Karonga Zungu <karongaz@netscape.net>'>
# None
# None
# None
# <re.Match object; span=(262, 303), match='To: Karonga Zungu <karongaz@netscape.net>'>
# <re.Match object; span=(241, 282), match='To: Karonga Zungu <karongaz@netscape.net>'>
# <re.Match object; span=(167, 208), match='To: Karonga Zungu <karongaz@netscape.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(267, 313), match='To: "Nepyyvoda Petro" <nepyyvoda@katamail.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(136, 174), match='To: "JAMES MORGAN" <dlkusov@berlin.de>'>
# None
# None
# None
# None
# <re.Match object; span=(316, 331), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(134, 151), match='To: "Rrrrr" <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(247, 303), match='To: sigmod-pods06-webmaster <sigmod-pods06-webmas>
# <re.Match object; span=(134, 151), match='To: "Rrrrr" <R@M>'>
# <re.Match object; span=(134, 151), match='To: "Rrrrr" <R@M>'>
# None
# <re.Match object; span=(289, 317), match='To: <markjames@socamail.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(321, 356), match='To: staff uba <staff_ubang@mail.ru>'>
# None
# None
# None
# <re.Match object; span=(328, 367), match='To: Mrs Rose David <rose_david@mail.ru>'>
# None
# <re.Match object; span=(281, 309), match='To: <markboland1990@tds.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(159, 188), match='To: <nenadonald02@centrum.cz>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(226, 269), match='To: "Harry Hilal" <harryhilal@netscape.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(336, 379), match='To: "mr. John Castro" <johncastro1@mail.ru>'>
# None
# None
# None
# <re.Match object; span=(455, 489), match='To: <princessfayad@worldmedic.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(340, 371), match='To: JOY IBE <mrsjoyibe@mail.ru>'>
# None
# None
# None
# <re.Match object; span=(599, 662), match='To: "barr stuart fielding (esq)" <stuartfielding@>
# None
# None
# None
# None
# <re.Match object; span=(228, 243), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(149, 158), match='To: <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(297, 328), match='To: <w.international@tesco.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(145, 160), match='To: rrrrr <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(506, 548), match='To: "jim owens" <jim_private100@yahoo.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(172, 219), match='To: ELIZABETH LAMINE <elizabeth_lamine@mail.ru>'>
# None
# <re.Match object; span=(151, 176), match='To: <murray01@centrum.cz>'>
# <re.Match object; span=(239, 300), match='To: "mary_20bamba@latinmail.com" <mary_20bamba@la>
# None
# <re.Match object; span=(242, 270), match='To: <martinmccourt1@msn.com>'>
# None
# None
# <re.Match object; span=(243, 278), match='To: <george_benneth@btinternet.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(316, 331), match='To: rrrrr <R@M>'>
# <re.Match object; span=(318, 333), match='To: rrrrr <R@M>'>
# None
# None
# <re.Match object; span=(253, 306), match='To: "david505@adinet.com.uy" <david505@adinet.com>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(332, 370), match='To: "mrcliveosborn@netscape.net" <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(324, 361), match='To: james patrick <jamesf001@mail.ru>'>
# <re.Match object; span=(333, 359), match='To: <webmaster@aclweb.org>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(235, 296), match='To: "dr_idris_ali@latinmail.com" <dr_idris_ali@la>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(238, 299), match='To: "emeson_joe02@latinmail.com" <emeson_joe02@la>
# <re.Match object; span=(238, 299), match='To: "emeson_joe02@latinmail.com" <emeson_joe02@la>
# <re.Match object; span=(238, 299), match='To: "emeson_joe02@latinmail.com" <emeson_joe02@la>
# None
# <re.Match object; span=(139, 200), match='To: "emeson_joe02@latinmail.com" <emeson_joe02@la>
# None
# None
# None
# <re.Match object; span=(511, 557), match='To: stanly edward <stanly.edward4@yahoo.co.uk>'>
# None
# None
# None
# None
# <re.Match object; span=(451, 490), match='To: "Mr. Moore" <paul_moore1@myway.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(153, 179), match='To: <e_rogers1@centrum.cz>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(250, 319), match='To: "mustafa_joseph01@latinmail.com" <mustafa_jos>
# None
# <re.Match object; span=(271, 299), match='To: <linda_kolo3@centrum.cz>'>
# None
# <re.Match object; span=(335, 350), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(261, 310), match='To: "mjerry@adinet.com.uy" <mjerry@adinet.com.uy>>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(236, 295), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(236, 295), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(236, 295), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(236, 295), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(137, 196), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(137, 196), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(137, 196), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# <re.Match object; span=(236, 295), match='To: "joe_kekabu4@latinmail.com" <joe_kekabu4@lati>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(240, 255), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(216, 249), match='To: <sadra_victor2005@centrum.cz>'>
# None
# <re.Match object; span=(237, 262), match='To: <ianreed@ianmail.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(284, 311), match='To: <stephenwong@whbhk.com>'>
# None
# <re.Match object; span=(99, 154), match='To: "Barr.Charles Brown" <chambers02files@univers>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(520, 572), match='To: "williamspadmore" <williamspadmore@terra.com.>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(210, 240), match='To: <mariam_afonso@centrum.cz>'>
# <re.Match object; span=(136, 195), match='To: "musa_sani00@latinmail.com" <musa_sani00@lati>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(246, 311), match='To: "azize_ouattara@latinmail.com" <azize_ouattar>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(93, 135), match='To: "steven taha" <stvtaqp@rediffmail.com>'>
# None
# None
# None
# None
# <re.Match object; span=(210, 240), match='To: <joywilliams02@centrum.cz>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(155, 179), match='To: <angkote1@yahoo.com>'>
# <re.Match object; span=(233, 248), match='To: rrrrr <R@M>'>
# None
# <re.Match object; span=(239, 300), match='To: "bala_tomson3@latinmail.com" <bala_tomson3@la>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(139, 200), match='To: "ben_coroma75@latinmail.com" <ben_coroma75@la>
# None
# None
# <re.Match object; span=(123, 140), match='To: "Rrrrr" <R@M>'>
# None
# <re.Match object; span=(196, 217), match='To: "Webmaster" <R@M>'>
# None
# None
# None
# <re.Match object; span=(234, 291), match='To: "john_jacob@latinmail.com" <john_jacob@latinm>
# None
# <re.Match object; span=(240, 301), match='To: "jamessakato2@latinmail.com" <jamessakato2@la>
# <re.Match object; span=(240, 301), match='To: "jamessakato2@latinmail.com" <jamessakato2@la>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(138, 197), match='To: "mose_maliki@latinmail.com" <mose_maliki@lati>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(605, 647), match='To: "Doris Luanda" <luandad2006@yahoo.com>'>
# None
# None
# <re.Match object; span=(518, 578), match='To: <20051111081006.81883.qmail@web34009.mail.mud>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(178, 208), match='To: <elinaboleti2@virgilio.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(327, 378), match='To: "jenniferwils@terra.es" <jenniferwils@terra.e>
# <re.Match object; span=(327, 378), match='To: "jenniferwils@terra.es" <jenniferwils@terra.e>
# None
# <re.Match object; span=(327, 378), match='To: "jenniferwils@terra.es" <jenniferwils@terra.e>
# None
# <re.Match object; span=(131, 184), match='To: "faith5ad@latinmail.com" <faith5ad@latinmail.>
# None
# None
# None
# <re.Match object; span=(251, 277), match='To: <mutbarth@infinito.it>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(189, 229), match='To: "Lon Morton" <tkwdd@dunn-carney.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(140, 197), match='To: "rose_c2006@latinmail.com" <rose_c2006@latinm>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(147, 210), match='To: "pio_mohammed1@latinmail.com" <pio_mohammed1@>
# None
# None
# None
# None
# None
# <re.Match object; span=(161, 207), match='To: "WEST BANK" <dkscotdavidiinxr@yahoo.co.uk>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(180, 234), match='To: "Larisa Sosnitskaya" <mrcliveosborne@netscape>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(182, 208), match='To: <no-repllly@Chase.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(141, 202), match='To: "linda_kokori@latinmail.com" <linda_kokori@la>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(141, 202), match='To: "alicelacson8@latinmail.com" <alicelacson8@la>
# None
# <re.Match object; span=(144, 209), match='To: "musagaruba2005@latinmail.com" <musagaruba200>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(241, 294), match='To: "faith5ad@latinmail.com" <faith5ad@latinmail.>
# None
# None
# None
# <re.Match object; span=(241, 302), match='To: "florenceeteh@latinmail.com" <florenceeteh@la>
# None
# <re.Match object; span=(232, 285), match='To: "smart_60@latinmail.com" <smart_60@latinmail.>
# None
# None
# None
# None
# <re.Match object; span=(338, 379), match='To: helen williams <williams_405@mail.ru>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(256, 311), match='To: "drphilipk@adinet.com.uy" <drphilipk@adinet.c>
# None
# None
# <re.Match object; span=(157, 186), match='To: <nelson_l_keren@yahoo.fr>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(252, 273), match='To: <gakwesi@cool.la>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(240, 266), match='To: <zhanghe_1967@163.com>'>
# None
# None
# None
# <re.Match object; span=(118, 127), match='To: <R@M>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(248, 317), match='To: "garuba_umaru2005@latinmail.com" <garuba_umar>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(205, 236), match='To: "ppw9500@excite.com " <R@M>'>
# None
# None
# <re.Match object; span=(88, 114), match='To: <zhanghe_1967@163.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(189, 206), match='To: "rrrrr" <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(162, 184), match='To: <drlehadi@aol.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(228, 279), match='To: "joe4jkk@latinmail.com" <joe4jkk@latinmail.co>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(228, 279), match='To: "joe4jkk@latinmail.com" <joe4jkk@latinmail.co>
# None
# None
# None
# None
# None
# <re.Match object; span=(134, 149), match='To: rrrrr <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(241, 256), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(435, 482), match='To: "eric morgan " <eric.morgan001@yahoo.co.uk>'>
# None
# None
# None
# <re.Match object; span=(129, 144), match='To: rrrrr <R@S>'>
# None
# <re.Match object; span=(249, 316), match='To: "abdulaye_baraze@latinmail.com" <abdulaye_bar>
# <re.Match object; span=(129, 144), match='To: rrrrr <R@S>'>
# None
# None
# <re.Match object; span=(141, 204), match='To: "justus_lee002@latinmail.com" <justus_lee002@>
# None
# <re.Match object; span=(144, 159), match='To: rrrrr <R@S>'>
# <re.Match object; span=(144, 173), match='To: daemon <daemon@zendo.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(243, 306), match='To: "seyes_campury@latinmail.com" <seyes_campury@>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(241, 304), match='To: "musa_garuba55@latinmail.com" <musa_garuba55@>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(230, 245), match='To: rrrrr <R@M>'>
# None
# None
# None
# <re.Match object; span=(232, 285), match='To: "sulemanz@latinmail.com" <sulemanz@latinmail.>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(234, 293), match='To: "joe_alex1bf@latinmail.com" <joe_alex1bf@lati>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(130, 145), match='To: rrrrr <R@S>'>
# <re.Match object; span=(227, 242), match='To: rrrrr <R@M>'>
# None
# <re.Match object; span=(319, 359), match='To: "Comhghall Partin" <odil@bonide.com>'>
# None
# None
# None
# None
# <re.Match object; span=(227, 242), match='To: rrrrr <R@M>'>
# None
# <re.Match object; span=(317, 362), match='To: "jonesalun@terra.es" <jonesalun@terra.es>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(240, 255), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# <re.Match object; span=(231, 246), match='To: rrrrr <R@M>'>
# None
# None
# <re.Match object; span=(341, 397), match='To: sigmod-pods06-webmaster <sigmod-pods06-webmas>
# None
# None
# <re.Match object; span=(91, 123), match='To: <mrslisasuzuki4@yahoo.co.uk>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(335, 372), match='To: Bryan Kanza <bryankanza@inbox.ru>'>
# <re.Match object; span=(365, 380), match='To: <nlp@cs.CU>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(227, 242), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(248, 315), match='To: "mohammed_hassan@latinmail.com" <mohammed_has>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(325, 340), match='To: rrrrr <R@M>'>
# None
# <re.Match object; span=(177, 234), match='To: "princewill34@mixmail.com" <princewill34@mixm>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(131, 146), match='To: rrrrr <R@S>'>
# None
# None
# <re.Match object; span=(136, 157), match='To: <info@fx-time.ru>'>
# None
# None
# None
# <re.Match object; span=(242, 257), match='To: rrrrr <R@M>'>
# <re.Match object; span=(243, 258), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(470, 509), match='To: giorgi krissy <acl-exec@aclweb.org>'>
# None
# None
# None
# <re.Match object; span=(240, 255), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(185, 217), match='To: <peace_activist46@yahoo.com>'>
# None
# None
# <re.Match object; span=(218, 233), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(1308, 1346), match='To: "\'David Farber\'" <dave@farber.net>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(306, 347), match='To: "sa_dlo1@terra.es" <sa_dlo1@terra.es>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(174, 202), match='To: <rita_doink@virgilio.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(134, 149), match='To: rrrrr <R@S>'>
# None
# None
# None
# None
# <re.Match object; span=(329, 354), match='To: "Administrator" <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(6910, 6933), match='To: <joykem@centrum.sk>'>
# None
# None
# None
# None
# <re.Match object; span=(708, 752), match='To: Razaq Samiu <yvette.oldenburger@home.nl>'>
# None
# <re.Match object; span=(234, 249), match='To: rrrrr <R@M>'>
# <re.Match object; span=(519, 563), match='To: Razaq Samiu <yvette.oldenburger@home.nl>'>
# None
# None
# <re.Match object; span=(269, 301), match='To: <peace_activist50@yahoo.com>'>
# <re.Match object; span=(417, 451), match='To: <mrmikezanko18@rediffmail.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(241, 256), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(379, 399), match='To: <ttss@yahoo.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(210, 240), match='To: <alfred_kone22@centrum.cz>'>
# <re.Match object; span=(281, 331), match='To: "lacson alice" <lacson_alice2004@yahoo.com.ph>
# None
# None
# None
# <re.Match object; span=(357, 378), match='To: <jhagis3@mail.mn>'>
# <re.Match object; span=(269, 290), match='To: <jhagis3@mail.mn>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(208, 225), match='To: "rrrrr" <R@M>'>
# <re.Match object; span=(206, 223), match='To: "rrrrr" <R@M>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(240, 255), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(281, 309), match='To: "" <ali_mohdr@yahoo.com>'>
# None
# <re.Match object; span=(219, 234), match='To: rrrrr <R@M>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(340, 397), match='To: "david1111kalabi@terra.es" <david1111kalabi@t>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(170, 221), match='To: "Mrs. Tonia Van Smith" <leedcbknsewjoo@aim.co>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(311, 354), match='To: "markwwww@terra.es" <markwwww@terra.es>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(227, 242), match='To: rrrrr <R@M>'>
# <re.Match object; span=(369, 407), match='To: "LETTER FROM MR.JOSEPH POON" <R@M>'>
# None
# None
# None
# <re.Match object; span=(295, 326), match='To: <mark_ibe02@elsalvador.com>'>
# None
# None
# None
# None
# <re.Match object; span=(146, 163), match='To: "rrrrr" <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(235, 290), match='To: "sulemanzz@latinmail.com" <sulemanzz@latinmai>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(592, 618), match='To: <derek17800@yahoo.com>'>
# None
# None
# None
# <re.Match object; span=(350, 384), match='To: muthar ige <muthar1k@yahoo.no>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(393, 414), match='To: <info@parker.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(412, 438), match='To: <mrrmaria@socorro.com>'>
# <re.Match object; span=(412, 438), match='To: <mrrmaria@socorro.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(130, 139), match='To: <R@M>'>
# <re.Match object; span=(253, 295), match='To: <kennethcolemailcom@thestudentzon.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(113, 130), match='To: "rrrrr" <R@S>'>
# None
# None
# <re.Match object; span=(304, 313), match='To: <R@S>'>
# None
# None
# <re.Match object; span=(245, 312), match='To: "saku_watara2007@latinmail.com" <saku_watara2>
# None
# None
# None
# None
# None
# <re.Match object; span=(174, 183), match='To: <R@S>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(168, 193), match='To: <r.doink@virgilio.it>'>
# <re.Match object; span=(307, 316), match='To: <R@M>'>
# None
# <re.Match object; span=(299, 324), match='To: "Rachael Oniga" <R@S>'>
# None
# None
# None
# <re.Match object; span=(313, 356), match='To: "linda1m1@terra.es" <linda1m1@terra.es>'>
# None
# None
# None
# <re.Match object; span=(350, 413), match='To: "evansonumba16@tiscali.co.uk" <evansonumba16@>
# None
# None
# None
# None
# <re.Match object; span=(399, 415), match='To: <olssonk@UM>'>
# None
# None
# None
# None
# <re.Match object; span=(216, 248), match='To: <frank_hilary2007@yahoo.com>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(216, 240), match='To: <jeff_murd@yahoo.fr>'>
# <re.Match object; span=(317, 344), match='To: <shoulson@cs.CU>, <R@C>'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(215, 247), match='To: <missmiriamkolo11@myway.com>'>
# None
# None
# None
# <re.Match object; span=(213, 240), match='To: <drfrankwest@myway.com>'>
# <re.Match object; span=(408, 459), match='To: "Ken Saro-wiwa Jr." <ken_sorowiwajr@excite.co>
# <re.Match object; span=(446, 473), match='To: <j_camara2007@yahoo.fr>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(268, 293), match='To: <martins@ab-sa.co.za>'>
# None
# None
# <re.Match object; span=(325, 348), match='To: <helen@ab-sa.co.za>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(248, 317), match='To: "mr_hassanbilly01@latinmail.com" <mr_hassanbi>
# None
# None
# None
# <re.Match object; span=(217, 251), match='To: <frankkone0012000@yahoo.co.jp>'>
# <re.Match object; span=(217, 251), match='To: <frankkone0012000@yahoo.co.jp>'>
# None
# <re.Match object; span=(305, 344), match='To: "pae.za@terra.es" <pae.za@terra.es>'>
# <re.Match object; span=(192, 259), match='To: "MRS. LARISA SOSNITSKAYA" <larisasosnkayapofe>
# <re.Match object; span=(269, 298), match='To: <overlobe@ozemail.com.au>'>
# None
# None
# None
# None
# <re.Match object; span=(331, 356), match='To: <info@bebemous.co.za>'>
# None
# None
# <re.Match object; span=(220, 253), match='To: <attahmarieange2005@yahoo.fr>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(215, 238), match='To: <koutaba1@yahoo.fr>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(210, 235), match='To: <gmboma2@yahoo.co.uk>'>
# None
# None
# None
# <re.Match object; span=(216, 239), match='To: <koutaba1@yahoo.fr>'>
# <re.Match object; span=(218, 250), match='To: <drahmed_shalaa55@myway.com>'>
# None
# None
# None
# <re.Match object; span=(216, 240), match='To: <amija_aj@myway.com>'>
# None
# None
# None
# <re.Match object; span=(216, 241), match='To: <bencoroma@myway.com>'>
# <re.Match object; span=(192, 259), match='To: "MRS. LARISA SOSNITSKAYA" <larisasosnkayapawo>
# <re.Match object; span=(256, 279), match='To: <jones@ab-sa.co.za>'>
# None
# None
# <re.Match object; span=(314, 323), match='To: <R@S>'>
# <re.Match object; span=(370, 403), match='To: "" <j_roberts002@yahoo.co.uk>'>
# None
# None
# <re.Match object; span=(215, 243), match='To: <john_ali8080@yahoo.com>'>
# None
# None
# None
# None
# None
# <re.Match object; span=(215, 251), match='To: <nabjib_ibrahim_bf1@yahoo.co.uk>'>
# <re.Match object; span=(215, 251), match='To: <nabjib_ibrahim_bf1@yahoo.co.uk>'>
# None
# <re.Match object; span=(223, 251), match='To: <fr_thambo115@yahoo.com>'>
# <re.Match object; span=(221, 249), match='To: <musa_saladin@myway.com>'>
# <re.Match object; span=(189, 206), match='To: "rrrrr" <R@M>'>
# <re.Match object; span=(137, 155), match='To: N/A <>, N/A <>'>
# None
# None
# None
# <re.Match object; span=(137, 147), match='To: N/A <>'>
# <re.Match object; span=(216, 254), match='To: <mrstheresacolemanpri@yahoo.co.jp>'>
# None
# None
# None
# <re.Match object; span=(212, 240), match='To: <mrpleon07@yahoo.com.hk>'>
# <re.Match object; span=(222, 249), match='To: <chantal_koik@yahoo.fr>'>
# <re.Match object; span=(222, 249), match='To: <chantal_koik@yahoo.fr>'>
# None
# None
# <re.Match object; span=(318, 336), match='To: <irs.@irs.gov>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(219, 248), match='To: <geraldzongo004@yahoo.fr>'>
# <re.Match object; span=(212, 239), match='To: <chantal_koik@yahoo.fr>'>
# <re.Match object; span=(224, 258), match='To: <princess_gesinta206@yahoo.fr>'>
# None
# None
# <re.Match object; span=(97, 130), match='To: <coalition_protect1@yahoo.fr>'>
# <re.Match object; span=(91, 118), match='To: <r.akintunde1@yahoo.it>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(177, 216), match='To: "Dear Sir" <kimati.didan@gmail.com>'>
# <re.Match object; span=(219, 241), match='To: <mrlaad@myway.com>'>
# None
# <re.Match object; span=(210, 237), match='To: <mik_kone2002@yahoo.fr>'>
# <re.Match object; span=(142, 164), match='To: <eyorfke@yahoo.dk>'>
# None
# None
# None
# None
# <re.Match object; span=(434, 461), match='To: <mik_kone2002@yahoo.fr>'>
# <re.Match object; span=(215, 240), match='To: <tonywach50@yahoo.no>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(219, 249), match='To: <idris_makafi01@myway.com>'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(408, 436), match='To: <jen_marthin01@yahoo.fr>'>
# None
# None
# None
# <re.Match object; span=(213, 241), match='To: <vincentyuval1@yahoo.it>'>
# None
# <re.Match object; span=(223, 254), match='To: <kanazoe_alidaa1@myway.com>'>
# <re.Match object; span=(219, 256), match='To: <williamsandsusan180@yahoo.co.uk>'>
# <re.Match object; span=(229, 278), match='To: "bajoga@latinmail.com" <bajoga@latinmail.com>>
# None
# None
# <re.Match object; span=(347, 386), match='To: Jaron Abbas <jaron_abbass@yahoo.de>'>
# <re.Match object; span=(347, 386), match='To: Jaron Abbas <jaron_abbass@yahoo.de>'>
# <re.Match object; span=(216, 243), match='To: <adams_swill1@yahoo.fr>'>
# None
# <re.Match object; span=(241, 298), match='To: "gosolanges@latinmail.com" <gosolanges@latinm>
# <re.Match object; span=(215, 242), match='To: <ddjedjess002@yahoo.fr>'>
# <re.Match object; span=(220, 247), match='To: <adams.kabora@yahoo.fr>'>
# <re.Match object; span=(220, 247), match='To: <adams.kabora@yahoo.fr>'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(419, 448), match='To: <isedore.lawan@gmail.com>'>
# None
# None
# None
# <re.Match object; span=(219, 245), match='To: <felissajan@yahoo.com>'>
# None
# <re.Match object; span=(387, 425), match='To: "" <sunocosunoilcompany@myway.com>'>
# <re.Match object; span=(387, 425), match='To: "" <sunocosunoilcompany@myway.com>'>
# <re.Match object; span=(221, 252), match='To: <joelthomson03@jmail.co.za>'>
# None
# None
# <re.Match object; span=(91, 117), match='To: <stevelee373@sify.com>'>
# None
# None
# None
# None
# <re.Match object; span=(358, 393), match='To: <oo.oo.oo.oo.oo.oo@hotmail.com>'>
# None
# <re.Match object; span=(353, 388), match='To: <oo.oo.oo.oo.oo.oo@hotmail.com>'>
# None
# None
# <re.Match object; span=(163, 205), match='To: <julia.chen.shenhua.group@hotmail.com>'>
# <re.Match object; span=(215, 241), match='To: <mrmansouri1@yahoo.fr>'>
# <re.Match object; span=(216, 241), match='To: <kali_oddo1@yahoo.fr>'>
# <re.Match object; span=(251, 322), match='To: "jamesbongani10015@latinmail.com" <jamesbonga>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(214, 241), match='To: <henry_chuks@myway.com>'>
# <re.Match object; span=(214, 240), match='To: <abl_musa20@myway.com>'>
# None
# <re.Match object; span=(217, 246), match='To: <idris.adamu001@yahoo.fr>'>
# <re.Match object; span=(216, 242), match='To: <kennethobi@gmail.com>'>
# <re.Match object; span=(122, 153), match='To: <info.financialci@yahoo.fr>'>
# None
# None
# <re.Match object; span=(219, 251), match='To: <motherdorisk9@yahoo.com.hk>'>
# <re.Match object; span=(156, 195), match='To: <oooooooooo_aaaaaaaaaa@hotmail.com>'>
# None
# None
# <re.Match object; span=(218, 249), match='To: <ali_sherif105@yahoo.co.uk>'>
# <re.Match object; span=(221, 252), match='To: <drusmanibrahim.tg@homs.cc>'>
# <re.Match object; span=(131, 163), match='To: <motherdorisk9@yahoo.com.hk>'>
# None

# %%
emails_df = pd.DataFrame(emails)
emails_df.head(10)
# Out:
#                     sender_email             sender_name recipient_email  \
# 0    james_ngola2002@maktoob.com        MR. JAMES NGOLA.            None
# 1   bensul2004nng@spinfinder.com         Mr. Ben Suleman            None
# 2           obong_715@epatra.com      PRINCE OBONG ELEME            None
# 3           obong_715@epatra.com      PRINCE OBONG ELEME            None
# 4             m_abacha03@www.com           Maryam Abacha            None
# 5         davidkuta@postmark.net              Kuta David            None
# 6         tunde_dosumu@lycos.com  Barrister tunde dosumu            None
# 7  william2244drallo@maktoob.com          William Drallo            None
# 8       abdul_817@rediffmail.com          MR USMAN ABDUL            None
# 9         barrister_td@lycos.com           Tunde  Dosumu            None
#
#   recipient_name    date_sent                                     subject
# 0           None  31 Oct 2002  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1           None  31 Oct 2002         URGENT ASSISTANCE /RELATIONSHIP (P)
# 2           None  31 Oct 2002                             GOOD DAY TO YOU
# 3           None  31 Oct 2002                             GOOD DAY TO YOU
# 4           None   1 Nov 2002                     I Need Your Assistance.
# 5           None  02 Nov 2002                                 Partnership
# 6           None         None                            Urgent Attention
# 7           None   3 Nov 2002                     URGENT BUSINESS PRPOSAL
# 8           None  04 Nov 2002                                   THANK YOU
# 9           None         None                           Urgent Assistance

# %%
emails_df.to_csv(f"{student1_section}_{student1_BN}_{student2_section}_{student2_BN}.csv", index=False)
